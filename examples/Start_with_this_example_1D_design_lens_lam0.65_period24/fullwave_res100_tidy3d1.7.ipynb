# %% [markdown]
# # wavelength 0.65nm

# %%
import sys
module_path = 'C:/Users/94735/OneDrive - UW-Madison/My Projects/CMT_and_inverse_design/Meta_SCMT'
sys.path.insert(1, module_path)
import Meta_SCMT
import numpy as np
import matplotlib.pyplot as plt

# %%
GP = {
    'dim' : 1, #dim : 1 or 2.
    'modes' : 1, #number of modes with in a single waveguide. modes <= 2 is usually good enough.
    'period' : 0.24,
    'res' : 20, #resolution within one period
    'downsample_ratio': 1, #between (0, 1] for the output periodic resolution, it will be int(round(downsample_ratio * res))
    'wh' : 0.8, #waveguide height
    'lam' : 0.65,
    'n_sub' : 1.46, #the refractive index of substrate.
    'n_wg' : 2.27,# the refractive index of waveguide
    'h_min' : 0.03, #h_min, and h_max define the range of the width of waveguide.
    'h_max' : 0.23,
    'dh' : 0.01, #the step size of h.
    'path' : "sim_cache_650nm/", #the inter state store path            
}
sim = Meta_SCMT.Sim(**GP)

# %% [markdown]
# # step 4.1 we do a fullwave simulation using Tidy3d to validate our forward process.

# %%
N = 100
theta = 0
NA = 0.8
prop_dis = 0.5 * N * GP['period'] * np.sqrt((1 - NA**2)/NA**2)
_, wgs = sim.PBA.design_lens(N, prop_dis, load = True)
#np.save(f"PBA_lens_N{N}_lam{GP['lam']}um.npy", wgs)
#wgs = np.random.uniform(GP['h_min'], GP['h_max'], (N,))
#np.save(f"random_wgs2_N{N}_lam{GP['lam']}um.npy", wgs)
#wgs = np.load(f"random_wgs2_N{N}_lam{GP['lam']}um.npy")

# %%
phases = sim.PBA.width_to_phase(wgs, sim.GP.period, load = True, vis = True)

# %%
amps = sim.PBA.width_to_amp(wgs, sim.GP.period, load = True, vis = True)

# %%
sim.scmt.init_model(N, prop_dis, COUPLING = True, init_hs= wgs, far_field= False)
E_out =sim.scmt.forward(theta = theta)
#np.save("E_out_correct_freespace2_wg_coupling.npy", E_out)
sim.scmt.vis_field(E_out)
E_scmt = E_out
# Out:
# coo_sparse generated.
# coo_sparse generated.
# dis model input generated.
# initialized by loaded h_paras.

# %%
sim.scmt.init_model(N, prop_dis, COUPLING = True, init_hs= wgs, far_field= True)
E_out =sim.scmt.forward(theta = theta)
I1_far = np.abs(E_out)**2
sim.scmt.vis_field(I1_far)
# Out:
# coo_sparse generated.
# coo_sparse generated.
# dis model input generated.
# f_kernel generated.
# initialized by loaded h_paras.

# %%
sim.scmt.init_model(N, prop_dis, COUPLING = False, init_hs= wgs, far_field= False)
E_out =sim.scmt.forward(theta = theta)
sim.scmt.vis_field(E_out)
E_no_coupling = E_out
# Out:
# coo_sparse generated.
# coo_sparse generated.
# dis model input generated.
# initialized by loaded h_paras.

# %% [markdown]
# # fullwave

# %%
sim.fullwave.init_sim(prop_dis, N, wgs, res = 100, theta = theta, backend = 'tidy3d')
# Out:
# [20:45:19] INFO     Using client version: 1.7.1                                                      ]8;id=840622;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\__init__.py\__init__.py]8;;\:]8;id=259101;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\__init__.py#95\95]8;;\
# C:/Users/94735/OneDrive - UW-Madison/My Projects/CMT_and_inverse_design/Meta_SCMT\Meta_SCMT\fullwave_1D.py:203: UserWarning: Fullwave is expensive and slow. Only do fullwave on small devices. And low resolution can be inaccurate.
#   warnings.warn(
# Fullwave resolution: 100
# numerical aperture: 0.81
# total running time: 2.168166617840596e-12
# type='PlaneWave' center=(0.0, 0.0, -5.399999999999999) size=(inf, inf, 0.0) source_time=GaussianPulse(amplitude=1.0, phase=0.0, type='GaussianPulse', freq0=461219166355378.44, fwidth=46121916635537.84, offset=5.0) name=None direction='+' angle_theta=0.0 angle_phi=0.0 pol_angle=1.5707963267948966

# %%
sim.fullwave.upload(task_name="Feb26_2023_1D_lens_wgs_res100_N" + str(N))
sim.fullwave.download(data_path="output_tidy3d/")
# Out:
# [10:39:52] INFO     Using Tidy3D credentials from stored file.                                           ]8;id=224572;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\auth.py\auth.py]8;;\:]8;id=159700;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\auth.py#70\70]8;;\
# [10:39:53] INFO     Authentication successful.                                                           ]8;id=442806;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\auth.py\auth.py]8;;\:]8;id=951528;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\auth.py#30\30]8;;\
# [10:39:54] INFO     Uploaded task 'Feb26_2023_1D_lens_wgs_res100_N100' with task_id                   ]8;id=612005;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=554855;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#118\118]8;;\
#                     '4d9d29c7-593a-448f-9a1b-c9d159badb19'.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:39:57] INFO     Maximum flex unit cost: 0.20                                                      ]8;id=369083;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=472650;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#253\253]8;;\
#            INFO     status = queued                                                                   ]8;id=269550;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=916437;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#262\262]8;;\
# Output()
# [10:39:58] INFO     status = preprocess                                                               ]8;id=685658;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=233626;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#274\274]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [10:40:02] INFO     starting up solver                                                                ]8;id=39219;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=20164;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#278\278]8;;\
# [10:40:12] INFO     running solver                                                                    ]8;id=996766;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=971155;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#284\284]8;;\
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#            INFO     status = postprocess                                                              ]8;id=895300;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=477311;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#301\301]8;;\
# Output()
# [10:41:29] INFO     status = success                                                                  ]8;id=965645;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=23018;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#307\307]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# load data from sever:  True
# [10:41:30] INFO     downloading file "output/monitor_data.hdf5" to                                    ]8;id=162258;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=645875;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#579\579]8;;\
#                     "output_tidy3d/Feb26_2023_1D_lens_wgs_res100_N100/monitor_data.hdf5"
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [10:42:08] INFO     loading SimulationData from                                                       ]8;id=904638;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=898485;file://C:\Users\94735\AppData\Roaming\Python\Python38\site-packages\tidy3d\web\webapi.py#401\401]8;;\
#                     output_tidy3d/Feb26_2023_1D_lens_wgs_res100_N100/monitor_data.hdf5

# %%
path = "output_tidy3d/" + "Feb26_2023_1D_lens_wgs_res100_N" + str(N) +'/monitor_data.hdf5'
Ey_xz_raw, data_in, data_near, data_far = sim.fullwave.vis_monitor(path = path)

# %%
Ifw_far = np.abs(data_far['Ey'])**2
x = data_far['x']

# %%
def normalize(x):
    x = np.abs(x)
    x = x/x.max()
    return x

plt.figure()
plt.plot(x, normalize(Ifw_far), color = 'k', alpha = 0.9,label = 'Fullwave')
plt.plot(x, normalize(I1_far), label = 'SCMT',color = 'r', linestyle = '--', linewidth = 2)
plt.legend(fontsize = 16)
plt.xlabel('Position [um]',fontsize = 16)
plt.ylabel('Intensity',fontsize = 16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.savefig('far_field_Intensity_SCMT_phase_comparison_lens_tidy3d1.7.png', bbox_inches = 'tight')
plt.savefig('far_field_Intensity_SCMT_phase_comparison_lens_tidy3d1.7.eps', bbox_inches = 'tight')
# plt.savefig(f"amp_validation_incident_angle_{theta_deg:d}_deg.png", bbox_inches = 'tight')
# plt.savefig(f"amp_validation_incident_angle_{theta_deg:d}_deg.eps", bbox_inches = 'tight')
# Out:
# [10:56:27] WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=860023;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=175120;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=377702;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=503208;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=770612;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=575982;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=961843;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=316344;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.

# %%
sim.fullwave.results_analysis()
# Out:
# fwhm = 0.3300 um, 0.51 $\lambda$
# f_kernel generated.
# Model initialized.
# using device:  cuda
# I_in: 1.000000, I_out: 971.143188, I_out/I_in: 971.143188.
# Ideal focal area power/total_far_field_power = 94.07%
# fwhm_airy = 0.3300 um,  0.51 $\lambda$
# transmission efficiency = 83.07%
# far field efficiency = 77.46%
# focusing efficiency = 59.80%
# focal area power/total_far_field_power = 77.20%

# %%
# def cal_phase_dis(p1, p2):
#     N = p1.size
#     p1 = p1.reshape((N, 1))
#     p2 = p2.reshape((N, 1))
#     dis1 = (p1 - p2 - 2 * np.pi)**2
#     dis2 = (p1 - p2)**2
#     dis3 = (p1 - p2 + 2 * np.pi)**2
#     dis = np.c_[dis1, dis2, dis3]
#     dis = np.sum(np.min(dis, axis = -1))
#     return dis
# def cal_phase_dis2(p1, p2):
#     N = p1.size
#     res = 0
#     for i in range(N):
#         res += min((p1[i] - p2[i])**2, (p1[i] - p2[i] - 2 * np.pi)**2)
#     return res
def cal_phase_dis(p1, p2):
    #return np.sqrt(np.sum(np.abs(np.exp(1j * p1) - np.exp(1j * p2))**2)/p1.size)
    return np.sum(np.abs(np.exp(1j * p1) - np.exp(1j * p2)))/p1.size

# %%
def get_phase_offset(E1, E2):
    L2_dis = np.inf
    theta_opt = 0
    for theta in np.linspace(0, 2 * np.pi, 314 * 2):
        E_temp = E1 * np.exp(1j * theta)
        phase_temp = np.angle(E_temp)
        phase2 = np.angle(E2)
        #dis_temp = ((phase_temp - phase2)**2).sum()
        dis_temp = cal_phase_dis(phase_temp, phase2)
        if dis_temp < L2_dis:
            L2_dis = dis_temp
            theta_opt = theta
    print("minimum phase l2 dis:", L2_dis)
    return theta_opt

# %%
def cal_l2(E1, E2):
    ph1_offset = get_phase_offset(E1, E2)
    print("phase_offset:", ph1_offset)
    plt.figure(figsize = (20, 10))
    plt.plot(np.angle(E1 * np.exp(1j * ph1_offset)))
    plt.plot(np.angle(E2))
    p_scmt = np.angle(E1 * np.exp(1j * ph1_offset))
    p_fw = np.angle(E2)
    return cal_phase_dis(p_scmt, p_fw)

# %%
#L1 distance
E_fullwave = data_near['Ey']
x = data_near['x']
E_pba = np.exp(1j * phases)
px = (np.arange(E_pba.shape[0]) - (E_pba.shape[0] - 1)/2) * sim.GP.period
E_pba = np.interp(x, px, E_pba)
l2_tmp_pba = cal_l2(E_pba, E_fullwave)
print("L2 pba", l2_tmp_pba)
l2_tmp_scmt = cal_l2(E_scmt, E_fullwave)
print("L2 scmt", l2_tmp_scmt)
# Out:
# minimum phase l2 dis: 0.5826073177999319
# phase_offset: 4.739946810679338
# L2 pba 0.5826073177999319
# minimum phase l2 dis: 0.48799884521430476
# phase_offset: 0.5110724891007319
# L2 scmt 0.48799884521430476

# %%
E_fullwave = data_near['Ey']
x = data_near['x']
E_pba = np.exp(1j * phases)
px = (np.arange(E_pba.shape[0]) - (E_pba.shape[0] - 1)/2) * sim.GP.period
E_pba = np.interp(x, px, E_pba)
amp_pba = np.interp(x, px, amps)

# %%
pba_offset = get_phase_offset(E_pba, E_fullwave)
scmt_offset = get_phase_offset(E_scmt, E_fullwave)
no_coupling_offset = get_phase_offset(E_no_coupling, E_fullwave)
phase_pba = np.angle(E_pba * np.exp(1j * pba_offset))
phase_scmt = np.angle(E_scmt * np.exp(1j * scmt_offset))
phase_no_coupling = np.angle(E_no_coupling * np.exp(1j * no_coupling_offset))
phase_fw = np.angle(E_fullwave)
print("mean abs phase error pba: ", cal_phase_dis(phase_pba, phase_fw))
print("mean abs phase error scmt: ", cal_phase_dis(phase_scmt, phase_fw))
print("mean abs phase error no coupling: ", cal_phase_dis(phase_no_coupling, phase_fw))
# Out:
# minimum phase l2 dis: 0.5826073177999319
# minimum phase l2 dis: 0.48799884521430476
# minimum phase l2 dis: 0.5678397289753091
# mean abs phase error pba:  0.5826073177999319
# mean abs phase error scmt:  0.48799884521430476
# mean abs phase error no coupling:  0.5678397289753091

# %%
# def unroll_phase(phase):
#     offset = 0
#     N = phase.size
#     offsets = [offset]
#     for i in range(1, N):
#         if phase[i] - phase[i - 1] > 1* np.pi:
#             offset -= 2 * np.pi
#         if phase[i - 1] - phase[i] > 1 * np.pi:
#             offset += 2 * np.pi
#         offsets.append(offset)
#     offsets = np.array(offsets)
#     phase = phase + offsets
#     return phase

# %%
#make Fullwave close to SCMT
def preprocess_fullwave(ph_f, ph_scmt):
    for i in range(len(ph_f)):
        dis = abs(ph_f[i] - ph_scmt[i])
        dis1 = abs(ph_f[i] - ph_scmt[i] - 2 * np.pi)
        dis2 = abs(ph_f[i] - ph_scmt[i] + 2 * np.pi)
        if dis > dis1 and dis1 < 0.3 * np.pi:
            ph_f[i] -= 2 * np.pi
            dis = dis1
        if dis > dis2 and dis2 < 0.3 * np.pi:
            ph_f[i] += 2 * np.pi
            dis = dis2
    return ph_f

# %%
plt.figure()
plt.plot(x, phase_fw, color = 'k', label = 'Fullwave', alpha = 0.9)
plt.plot(x, phase_pba, color = 'r', label = 'LPA', linestyle = '--')
#plt.plot(x, phase_scmt, label = 'SCMT')
plt.xlabel(r'Position [$\mu$m]',fontsize = 16)
plt.ylabel('Phase [rad]',fontsize = 16)
plt.ylim(-4, 6)
plt.legend(fontsize = 16)

# %%
plt.figure()
plt.plot(x, phase_fw,color = 'k',  label = 'Fullwave', alpha = 0.8)
#plt.plot(x, phase_pba, label = 'LPA')
plt.plot(x, phase_scmt, color = 'r', label = 'SCMT', linestyle = '--')
plt.xlabel(r'Position [$\mu$m]',fontsize = 16)
plt.ylabel('Phase [rad]',fontsize = 16)
plt.ylim(-4, 6)
plt.legend(fontsize = 16)
plt.savefig('near_field_SCMT_phase_comparison_lens_tidy3d1.7.png')
plt.savefig('near_field_SCMT_phase_comparison_lens_tidy3d1.7.eps')
# Out:
# [10:46:32] WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=271960;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=168995;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=682221;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=722556;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=937965;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=241671;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=211388;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=108800;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.

# %%
amp_pba_norm = amp_pba / np.sqrt(np.sum(amp_pba**2))
amp_fullwave = np.abs(E_fullwave)
amp_fullwave_norm = amp_fullwave / np.sqrt(np.sum(amp_fullwave**2))
amp_scmt = np.abs(E_scmt)
amp_scmt_norm = amp_scmt / np.sqrt(np.sum(amp_scmt**2))
amp_no_coupling = np.abs(E_no_coupling)
amp_no_coupling_norm = amp_no_coupling / np.sqrt(np.sum(amp_no_coupling**2))

# %%
def cal_relative_err(x, ref):
    return np.sum(np.abs(x - ref)**2)/np.sum(np.abs(ref)**2)

# %%
plt.figure()
plt.plot(x, amp_fullwave_norm, color = 'k',label = 'Fullwave')
#plt.plot(x, phase_pba, label = 'LPA')
plt.plot(x, amp_scmt_norm,color = 'r', label = 'SCMT', linestyle = '--', alpha = 0.8)
plt.xlabel(r'Position [$\mu$m]',fontsize = 16)
plt.ylabel('Amplitude',fontsize = 16)
plt.ylim(0, 0.06)
plt.legend(fontsize = 16)
print("relative error%: ", cal_relative_err(amp_scmt_norm, amp_fullwave_norm) * 100)
plt.savefig('near_field_SCMT_amp_comparison_lens_tidy3d1.7.png')
plt.savefig('near_field_SCMT_amp_comparison_lens_tidy3d1.7.eps')
# Out:
# relative error%:  15.664965810631672
# [20:46:14] WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=800009;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=243803;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=392375;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=810982;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=408269;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=119558;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.
#            WARNING  The PostScript backend does not support transparency; partially transparent   ]8;id=114171;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py\backend_ps.py]8;;\:]8;id=686117;file://C:\Users\94735\.conda\envs\pytorch1.9_env\lib\site-packages\matplotlib\backends\backend_ps.py#734\734]8;;\
#                     artists will be rendered opaque.

# %%
plt.figure()
plt.plot(x, amp_fullwave_norm, color = 'k',label = 'Fullwave')
#plt.plot(x, phase_pba, label = 'LPA')
plt.plot(x, amp_no_coupling_norm, color = 'r',label = 'No coupling', linestyle = '--', alpha = 0.8)
plt.xlabel(r'Position [$\mu$m]',fontsize = 16)
plt.ylabel('Amplitude',fontsize = 16)
plt.ylim(0, 0.06)
plt.legend(fontsize = 16)
print("relative error%: ", cal_relative_err(amp_no_coupling_norm, amp_fullwave_norm) * 100)
# plt.savefig('near_field_no_coupling_amp_comparison_lens.png')
# plt.savefig('near_field_no_coupling_amp_comparison_lens.eps')
# Out:
# relative error%:  17.047422478473628

# %%
plt.figure()
plt.plot(x, amp_fullwave_norm, color = 'k',label = 'Fullwave')
#plt.plot(x, phase_pba, label = 'LPA')
plt.plot(x, amp_pba_norm, color = 'r',label = 'LPA', linestyle = '--', alpha = 0.8)
plt.xlabel(r'Position [$\mu$m]',fontsize = 16)
plt.ylabel('Amplitude',fontsize = 16)
plt.legend(fontsize = 16)
plt.ylim(0, 0.06)
print("relative error%: ", cal_relative_err(amp_pba_norm, amp_fullwave_norm) * 100)
# plt.savefig('near_field_LPA_amp_comparison_lens.png')
# plt.savefig('near_field_LPA_amp_comparison_lens.eps')
# Out:
# relative error%:  10.520952655285637
